# %%
## Making essential imports
import os
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf

# %%
## defining a frame for image and mask storage
framObjTrain = {'img' : [],
           'mask' : []
          }

framObjValidation = {'img' : [],
           'mask' : []
          }

## defining data Loader function
def LoadData( frameObj = None, imgPath = None, maskPath = None, shape = 256):
    imgNames = os.listdir(imgPath)
    maskNames = os.listdir(maskPath)
    
    # ## generating mask names
    # for mem in imgNames:
    #     maskNames.append(re.sub('\.png', '_L.png', mem))
    
    imgAddr = imgPath + '/'
    maskAddr = maskPath + '/'
    
    for i in range (len(imgNames)):
        img = plt.imread(imgAddr + imgNames[i])
        mask = plt.imread(maskAddr + maskNames[i])
        
        img = cv2.resize(img, (shape, shape)) 
        mask = cv2.resize(mask, (shape, shape))
        
        frameObj['img'].append(img)
        frameObj['mask'].append(mask)
        
    return frameObj

# %%
framObjTrain = LoadData( framObjTrain, imgPath = 'Amazon Forest Dataset/data/Training/images', 
                        maskPath = 'Amazon Forest Dataset/data/Training/masks', 
                        shape = 128)

# %%
framObjValidation  = LoadData( framObjValidation, imgPath = 'Amazon Forest Dataset/data/Validation/images', 
                              maskPath = 'Amazon Forest Dataset/data/Validation/masks',
                              shape = 128)

# %%
## displaying data loaded by our function
plt.subplot(1,2,1)
plt.imshow(framObjTrain['img'][1])
plt.subplot(1,2,2)
plt.imshow(framObjTrain['mask'][1])
plt.show()

# %%
# this block essentially performs 2 convolution
#     ValueError: Input 0 of layer "model" is incompatible with the layer: expected shape=(None, 128, 128, 3), found shape=(None, 256, 256, 3)


def Conv2dBlock(inputTensor, numFilters, kernelSize = 3, doBatchNorm = True):
    #first Conv
    x = tf.keras.layers.Conv2D(filters = numFilters, kernel_size = (kernelSize, kernelSize),
                              kernel_initializer = 'he_normal', padding = 'same') (inputTensor)
    
    if doBatchNorm:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x =tf.keras.layers.Activation('relu')(x)
    
    #Second Conv
    x = tf.keras.layers.Conv2D(filters = numFilters, kernel_size = (kernelSize, kernelSize),
                              kernel_initializer = 'he_normal', padding = 'same') (x)
    if doBatchNorm:
        x = tf.keras.layers.BatchNormalization()(x)
        
    x = tf.keras.layers.Activation('relu')(x)
    
    return x


# Now defining Unet 
def GiveMeUnet(inputImage, numFilters = 16, droupouts = 0.1, doBatchNorm = True):
    # defining encoder Path
    c1 = Conv2dBlock(inputImage, numFilters * 1, kernelSize = 3, doBatchNorm = doBatchNorm)
    p1 = tf.keras.layers.MaxPooling2D((2,2))(c1)
    p1 = tf.keras.layers.Dropout(droupouts)(p1)
    
    c2 = Conv2dBlock(p1, numFilters * 2, kernelSize = 3, doBatchNorm = doBatchNorm)
    p2 = tf.keras.layers.MaxPooling2D((2,2))(c2)
    p2 = tf.keras.layers.Dropout(droupouts)(p2)
    
    c3 = Conv2dBlock(p2, numFilters * 4, kernelSize = 3, doBatchNorm = doBatchNorm)
    p3 = tf.keras.layers.MaxPooling2D((2,2))(c3)
    p3 = tf.keras.layers.Dropout(droupouts)(p3)
    
    c4 = Conv2dBlock(p3, numFilters * 8, kernelSize = 3, doBatchNorm = doBatchNorm)
    p4 = tf.keras.layers.MaxPooling2D((2,2))(c4)
    p4 = tf.keras.layers.Dropout(droupouts)(p4)
    
    c5 = Conv2dBlock(p4, numFilters * 16, kernelSize = 3, doBatchNorm = doBatchNorm)
    
    # defining decoder path
    u6 = tf.keras.layers.Conv2DTranspose(numFilters*8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = tf.keras.layers.concatenate([u6, c4])
    u6 = tf.keras.layers.Dropout(droupouts)(u6)
    c6 = Conv2dBlock(u6, numFilters * 8, kernelSize = 3, doBatchNorm = doBatchNorm)
    
    u7 = tf.keras.layers.Conv2DTranspose(numFilters*4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    
    u7 = tf.keras.layers.concatenate([u7, c3])
    u7 = tf.keras.layers.Dropout(droupouts)(u7)
    c7 = Conv2dBlock(u7, numFilters * 4, kernelSize = 3, doBatchNorm = doBatchNorm)
    
    u8 = tf.keras.layers.Conv2DTranspose(numFilters*2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = tf.keras.layers.concatenate([u8, c2])
    u8 = tf.keras.layers.Dropout(droupouts)(u8)
    c8 = Conv2dBlock(u8, numFilters * 2, kernelSize = 3, doBatchNorm = doBatchNorm)
    
    u9 = tf.keras.layers.Conv2DTranspose(numFilters*1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = tf.keras.layers.concatenate([u9, c1])
    u9 = tf.keras.layers.Dropout(droupouts)(u9)
    c9 = Conv2dBlock(u9, numFilters * 1, kernelSize = 3, doBatchNorm = doBatchNorm)
    
    output = tf.keras.layers.Conv2D(4, (1, 1), activation = 'sigmoid')(c9)
    model = tf.keras.Model(inputs = [inputImage], outputs = [output])
    return model

## instanctiating model
inputs = tf.keras.layers.Input((128, 128, 3))
callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
myTransformer = GiveMeUnet(inputs, droupouts= 0.07)
myTransformer.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'] )

# %%
## trainign our model
retVal = myTransformer.fit(np.array(framObjTrain['img']), np.array(framObjTrain['mask']), epochs = 150, callbacks=[callback], verbose = 1)
# Out:
# Epoch 1/150
# 1/1 [==============================] - 8s 8s/step - loss: 0.6070 - accuracy: 0.2841
# Epoch 2/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.5712 - accuracy: 0.2982
# Epoch 3/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.5457 - accuracy: 0.3138
# Epoch 4/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.5223 - accuracy: 0.3321
# Epoch 5/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.5002 - accuracy: 0.3504
# Epoch 6/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.4786 - accuracy: 0.3648
# Epoch 7/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.4566 - accuracy: 0.3774
# Epoch 8/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.4378 - accuracy: 0.3853
# Epoch 9/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.4208 - accuracy: 0.3931
# Epoch 10/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.4050 - accuracy: 0.4007
# Epoch 11/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3917 - accuracy: 0.4106
# Epoch 12/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3779 - accuracy: 0.4227
# Epoch 13/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3672 - accuracy: 0.4347
# Epoch 14/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3569 - accuracy: 0.4398
# Epoch 15/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3483 - accuracy: 0.4419
# Epoch 16/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3405 - accuracy: 0.4461
# Epoch 17/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3333 - accuracy: 0.4512
# Epoch 18/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3271 - accuracy: 0.4533
# Epoch 19/150
# 1/1 [==============================] - 3s 3s/step - loss: 0.3208 - accuracy: 0.4530
# Epoch 20/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.3162 - accuracy: 0.4513
# Epoch 21/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.3111 - accuracy: 0.4510
# Epoch 22/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.3068 - accuracy: 0.4522
# Epoch 23/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.3021 - accuracy: 0.4527
# Epoch 24/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2978 - accuracy: 0.4538
# Epoch 25/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2936 - accuracy: 0.4547
# Epoch 26/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2897 - accuracy: 0.4566
# Epoch 27/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2859 - accuracy: 0.4577
# Epoch 28/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2820 - accuracy: 0.4576
# Epoch 29/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2786 - accuracy: 0.4587
# Epoch 30/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2754 - accuracy: 0.4588
# Epoch 31/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2722 - accuracy: 0.4605
# Epoch 32/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2694 - accuracy: 0.4617
# Epoch 33/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2665 - accuracy: 0.4599
# Epoch 34/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2636 - accuracy: 0.4628
# Epoch 35/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2607 - accuracy: 0.4629
# Epoch 36/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2577 - accuracy: 0.4612
# Epoch 37/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2542 - accuracy: 0.4644
# Epoch 38/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2509 - accuracy: 0.4667
# Epoch 39/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2601 - accuracy: 0.4632
# Epoch 40/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2501 - accuracy: 0.4654
# Epoch 41/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2493 - accuracy: 0.4637
# Epoch 42/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2478 - accuracy: 0.4606
# Epoch 43/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2446 - accuracy: 0.4618
# Epoch 44/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2423 - accuracy: 0.4627
# Epoch 45/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2393 - accuracy: 0.4640
# Epoch 46/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2358 - accuracy: 0.4650
# Epoch 47/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2321 - accuracy: 0.4679
# Epoch 48/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2291 - accuracy: 0.4694
# Epoch 49/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2263 - accuracy: 0.4718
# Epoch 50/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2242 - accuracy: 0.4738
# Epoch 51/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2220 - accuracy: 0.4723
# Epoch 52/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2206 - accuracy: 0.4715
# Epoch 53/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2179 - accuracy: 0.4726
# Epoch 54/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2160 - accuracy: 0.4737
# Epoch 55/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2139 - accuracy: 0.4738
# Epoch 56/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2114 - accuracy: 0.4736
# Epoch 57/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2096 - accuracy: 0.4728
# Epoch 58/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2082 - accuracy: 0.4722
# Epoch 59/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2063 - accuracy: 0.4720
# Epoch 60/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2043 - accuracy: 0.4730
# Epoch 61/150
# 1/1 [==============================] - 5s 5s/step - loss: 0.2024 - accuracy: 0.4742
# Epoch 62/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.2010 - accuracy: 0.4747
# Epoch 63/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1992 - accuracy: 0.4739
# Epoch 64/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1976 - accuracy: 0.4738
# Epoch 65/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1959 - accuracy: 0.4744
# Epoch 66/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1939 - accuracy: 0.4747
# Epoch 67/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1925 - accuracy: 0.4745
# Epoch 68/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1910 - accuracy: 0.4748
# Epoch 69/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1893 - accuracy: 0.4755
# Epoch 70/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1878 - accuracy: 0.4759
# Epoch 71/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1864 - accuracy: 0.4754
# Epoch 72/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1850 - accuracy: 0.4751
# Epoch 73/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1834 - accuracy: 0.4761
# Epoch 74/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1821 - accuracy: 0.4762
# Epoch 75/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1803 - accuracy: 0.4760
# Epoch 76/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1792 - accuracy: 0.4760
# Epoch 77/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1776 - accuracy: 0.4768
# Epoch 78/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1763 - accuracy: 0.4771
# Epoch 79/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1747 - accuracy: 0.4766
# Epoch 80/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1736 - accuracy: 0.4763
# Epoch 81/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1723 - accuracy: 0.4766
# Epoch 82/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1708 - accuracy: 0.4773
# Epoch 83/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1694 - accuracy: 0.4776
# Epoch 84/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1683 - accuracy: 0.4774
# Epoch 85/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1671 - accuracy: 0.4776
# Epoch 86/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1656 - accuracy: 0.4773
# Epoch 87/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1644 - accuracy: 0.4776
# Epoch 88/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1632 - accuracy: 0.4777
# Epoch 89/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1620 - accuracy: 0.4781
# Epoch 90/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1608 - accuracy: 0.4786
# Epoch 91/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1597 - accuracy: 0.4782
# Epoch 92/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1584 - accuracy: 0.4784
# Epoch 93/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1572 - accuracy: 0.4784
# Epoch 94/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1560 - accuracy: 0.4785
# Epoch 95/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1551 - accuracy: 0.4786
# Epoch 96/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1540 - accuracy: 0.4788
# Epoch 97/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1529 - accuracy: 0.4793
# Epoch 98/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1518 - accuracy: 0.4790
# Epoch 99/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1505 - accuracy: 0.4789
# Epoch 100/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1494 - accuracy: 0.4794
# Epoch 101/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1484 - accuracy: 0.4796
# Epoch 102/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1472 - accuracy: 0.4796
# Epoch 103/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1463 - accuracy: 0.4798
# Epoch 104/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1453 - accuracy: 0.4799
# Epoch 105/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1443 - accuracy: 0.4797
# Epoch 106/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1434 - accuracy: 0.4800
# Epoch 107/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1424 - accuracy: 0.4802
# Epoch 108/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1411 - accuracy: 0.4799
# Epoch 109/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1404 - accuracy: 0.4800
# Epoch 110/150
# 1/1 [==============================] - 5s 5s/step - loss: 0.1392 - accuracy: 0.4809
# Epoch 111/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1383 - accuracy: 0.4809
# Epoch 112/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1372 - accuracy: 0.4807
# Epoch 113/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1363 - accuracy: 0.4808
# Epoch 114/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1356 - accuracy: 0.4807
# Epoch 115/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1345 - accuracy: 0.4809
# Epoch 116/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1336 - accuracy: 0.4810
# Epoch 117/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1326 - accuracy: 0.4812
# Epoch 118/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1318 - accuracy: 0.4813
# Epoch 119/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1310 - accuracy: 0.4814
# Epoch 120/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1302 - accuracy: 0.4815
# Epoch 121/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1291 - accuracy: 0.4812
# Epoch 122/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1285 - accuracy: 0.4814
# Epoch 123/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1273 - accuracy: 0.4815
# Epoch 124/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1265 - accuracy: 0.4818
# Epoch 125/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1257 - accuracy: 0.4819
# Epoch 126/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1249 - accuracy: 0.4819
# Epoch 127/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1240 - accuracy: 0.4817
# Epoch 128/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1232 - accuracy: 0.4817
# Epoch 129/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1224 - accuracy: 0.4819
# Epoch 130/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1217 - accuracy: 0.4819
# Epoch 131/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1207 - accuracy: 0.4820
# Epoch 132/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1200 - accuracy: 0.4821
# Epoch 133/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1193 - accuracy: 0.4822
# Epoch 134/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1183 - accuracy: 0.4824
# Epoch 135/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1177 - accuracy: 0.4823
# Epoch 136/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1170 - accuracy: 0.4821
# Epoch 137/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1161 - accuracy: 0.4822
# Epoch 138/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1154 - accuracy: 0.4824
# Epoch 139/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1147 - accuracy: 0.4825
# Epoch 140/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1139 - accuracy: 0.4825
# Epoch 141/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1133 - accuracy: 0.4825
# Epoch 142/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1124 - accuracy: 0.4825
# Epoch 143/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1117 - accuracy: 0.4827
# Epoch 144/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1110 - accuracy: 0.4827
# Epoch 145/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1104 - accuracy: 0.4827
# Epoch 146/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1097 - accuracy: 0.4825
# Epoch 147/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1090 - accuracy: 0.4827
# Epoch 148/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1082 - accuracy: 0.4827
# Epoch 149/150
# 1/1 [==============================] - 4s 4s/step - loss: 0.1077 - accuracy: 0.4827
# Epoch 150/150
# 1/1 [==============================] - 5s 5s/step - loss: 0.1069 - accuracy: 0.4828

# %%
plt.plot(retVal.history['loss'], label = 'training_loss')
plt.plot(retVal.history['accuracy'], label = 'training_accuracy')
plt.legend()
plt.grid(True)

# %%
## function for getting 16 predictions
def predict16 (valMap, model, shape = 256):
    ## getting and proccessing val data
    img = valMap['img']
    mask = valMap['mask']
    mask = mask[0:16]
    
    imgProc = img [0:16]
    imgProc = np.array(img)
    
    predictions = model.predict(imgProc)
    for i in range(len(predictions)):
        predictions[i] = cv2.merge((predictions[i,:,:,0],predictions[i,:,:,1],predictions[i,:,:,2],predictions[i,:,:,3]))
    
    return predictions, imgProc, mask
    

    
    
def Plotter(img, predMask, groundTruth):
    plt.figure(figsize=(7,7))
    
    plt.subplot(1,3,1)
    plt.imshow(img)
    plt.title('image')
    
    plt.subplot(1,3,2)
    plt.imshow(predMask)
    plt.title('Predicted Mask')
    
    plt.subplot(1,3,3)
    plt.imshow(groundTruth)
    plt.title('actual Mask')

# %%
sixteenPrediction, actuals, masks = predict16(framObjValidation, myTransformer)
# Out:
# 1/1 [==============================] - 0s 230ms/step

# %%
Plotter(actuals[1], sixteenPrediction[1], masks[1])

# %%
Plotter(actuals[3], sixteenPrediction[3], masks[3])
